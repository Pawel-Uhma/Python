# %% [markdown]
# Decision Tree Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Position_Salaries.csv")
X = data.iloc[:,1:-1].values
y = data.iloc[:,-1].values

# %%
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor(random_state=0)
tree.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X,y,color = 'red',label='y')
plt.plot(X_grid,tree.predict(X_grid),label = 'Tree')
plt.title('Tree')
plt.xlabel('Position level')
plt.ylabel('Salaries')
plt.legend()
plt.show()
# Out:
# C:\Users\pawel\AppData\Local\Temp\ipykernel_1940\3995708422.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X),max(X),0.1)
